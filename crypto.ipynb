# %%
import requests
import csv

# %%
url = "https://api.coincap.io/v2/assets"

headers = {
    "Content-Type": "application/json",
    "Accept":"application/json"
}
response = requests.request("GET", url, headers=headers, data={})
myjson = response.json()
print(myjson)
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19644331.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1278125883880.9365259068217469', 'volumeUsd24Hr': '13715210946.7682942676943541', 'priceUsd': '65063.3449355407687799', 'changePercent24Hr': '5.2722745982220803', 'vwap24Hr': '63580.7832173916190344', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120133136.7344542600000000', 'maxSupply': None, 'marketCapUsd': '421171410554.4587385179331993', 'volumeUsd24Hr': '7028578061.4032533516784915', 'priceUsd': '3505.8720849471210900', 'changePercent24Hr': '2.8488717605105625', 'vwap24Hr': '3479.9094909587979698', 'explorer': 'https://etherscan.io/'}, {'id': 'tether', 'rank': '3', 'symbol': 'USDT', 'name': 'Tether', 'supply': '99515227360.7681100000000000', 'maxSupply': None, 'marketCapUsd': '99696010560.2769806368200965', 'volumeUsd24Hr': '29830283370.9613657542174825', 'priceUsd': '1.0018166385617900', 'changePercent24Hr': '0.0753061065031076', 'vwap24Hr': '1.0007287909252913', 'explorer': 'https://www.omniexplorer.info/asset/31'}, {'id': 'binance-coin', 'rank': '4', 'symbol': 'BNB', 'name': 'BNB', 'supply': '166801148.0000000000000000', 'maxSupply': '166801148.0000000000000000', 'marketCapUsd': '69958931788.7492454738244800', 'volumeUsd24Hr': '498150409.2182168858126275', 'priceUsd': '419.4151696650747600', 'changePercent24Hr': '1.5847911306551467', 'vwap24Hr': '415.6638392380497193', 'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'}, {'id': 'solana', 'rank': '5', 'symbol': 'SOL', 'name': 'Solana', 'supply': '442942585.1635880500000000', 'maxSupply': None, 'marketCapUsd': '58316390822.2293660978655453', 'volumeUsd24Hr': '984473614.4845875997094132', 'priceUsd': '131.6567717251478350', 'changePercent24Hr': '1.6239645302988327', 'vwap24Hr': '130.7665886008986710', 'explorer': 'https://explorer.solana.com/'}, {'id': 'xrp', 'rank': '6', 'symbol': 'XRP', 'name': 'XRP', 'supply': '45404028640.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '29596767764.5845800985417920', 'volumeUsd24Hr': '874202667.7690468078730614', 'priceUsd': '0.6518533410163178', 'changePercent24Hr': '4.9659764600029832', 'vwap24Hr': '0.6327842471088622', 'explorer': 'https://xrpcharts.ripple.com/#/graph/'}, {'id': 'usd-coin', 'rank': '7', 'symbol': 'USDC', 'name': 'USDC', 'supply': '28930539309.1459730000000000', 'maxSupply': None, 'marketCapUsd': '28954538811.3921539028043856', 'volumeUsd24Hr': '1334327618.1652676554281806', 'priceUsd': '1.0008295559923625', 'changePercent24Hr': '0.0114471027058831', 'vwap24Hr': '1.0000532691348909', 'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'}, {'id': 'cardano', 'rank': '8', 'symbol': 'ADA', 'name': 'Cardano', 'supply': '35485427964.8330000000000000', 'maxSupply': '45000000000.0000000000000000', 'marketCapUsd': '27506759221.2086257869599450', 'volumeUsd24Hr': '643230294.2559271105222277', 'priceUsd': '0.7751564740453054', 'changePercent24Hr': '6.9489570729918475', 'vwap24Hr': '0.7514079769567824', 'explorer': 'https://cardanoexplorer.com/'}, {'id': 'dogecoin', 'rank': '9', 'symbol': 'DOGE', 'name': 'Dogecoin', 'supply': '143326206383.7052300000000000', 'maxSupply': None, 'marketCapUsd': '23063109049.0634179257249117', 'volumeUsd24Hr': '2518738439.2364613757947400', 'priceUsd': '0.1609134130524609', 'changePercent24Hr': '18.8911799947169867', 'vwap24Hr': '0.1530808211433343', 'explorer': 'http://dogechain.info/chain/Dogecoin'}, {'id': 'avalanche', 'rank': '10', 'symbol': 'AVAX', 'name': 'Avalanche', 'supply': '377252601.6085633000000000', 'maxSupply': '720000000.0000000000000000', 'marketCapUsd': '16253141516.3857836253484848', 'volumeUsd24Hr': '234949721.2696528049416244', 'priceUsd': '43.0829143313636242', 'changePercent24Hr': '1.0501848407044454', 'vwap24Hr': '42.8470685904400795' ...

# %%
ourdata =[]

csvheader = ['SYMBOL', 'NAME','PRICE(USD)']
for x in myjson['data']:
    listing = [x['symbol'],x['name'],x['priceUsd']]
    ourdata.append(listing)

    with open('crypto.csv','w',encoding='UTF8', newline='')as f:
        writer = csv.writer(f)

        writer.writerow(csvheader)
        writer.writerows(ourdata)

print('done')
# Out:
# done
